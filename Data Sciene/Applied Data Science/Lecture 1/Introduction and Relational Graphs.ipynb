# %% [markdown]
# # Applied Data Science 1
# ### Module Leader: Dr. William Cooper
# ## Introduction
# This module provides hands-on training using Python in techniques fundamental to data science; we will cover:
# <ul>
#     <li>How to prepare data and work with it.</li>
#     <li>How to analyse data and extract information.</li>
#     <li>How to visualise data.</li>
#     <li>Interpret and communicate the results.</li>
# </ul>
# The main python packages used in this module are:
# <ul>
#     <li>numpy -- numerical functions and arrays</li>
#     <li>matplotlib.pyplot -- plotting</li>
#     <li>pandas -- reading files and performing functions typical in data science</li>
#     <li>scikit-learn (sklearn) -- in the later part of the module, for fitting and clustering</li>
# </ul>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# You can work in either notebooks or in plain python scripts.
# You may also use any python package for your work, but beware that the use of any package not taught in this course is often suspect of academic misconduct.
#
#
# The topics covered in this module are:
# <ul>
#     <li>Relational graphs (e.g. line/scatter plots)</li>
#     <li>Categorical graphs (e.g. histograms/pie/bar charts)</li>
#     <li>Statistical graphs (e.g. heatmaps/box/violin/corner plots)</li>
#     <li>Basic statistics and distributions</li>
#     <li>Version control and best coding practices</li>
#     <li>Data cleaning and manipulation</li>
#     <li>Industry techniques</li>
#     <li>Fitting and clustering</li>
# </ul>
#
# All software is available on the university machines, including those in the computer labs.
# If you wish to work on a personal machine, we cannot offer any technical support for those but recommend installing python and packages through Anaconda.
# We highly recommend saving all files to your university OneDrive account, which has lots of storage room and can be accessed from any machine.
#
# ### Teaching
# There will be a weekly 1hr lecture from a jupyter notebook.
# Two of these lectures will be Q&A sessions, in the weeks you have an assignment due.
# These weekly notebooks will also contain empty cells designed for you to fill in (either alone, or with friends) during the weekly 2hr tutorials, with support available from the tutors.
# You are expected to spend about 15 hours per week (3 scheduled hours + 12 study hours) on this module. If you do so, the assignments will be considerably easier!
#
# You will also have the opportunity to take hundreds of datacamp courses, for free! Follow the [link](https://www.datacamp.com/groups/shared_links/e9c1f873562a8a7bd87793b444b531f6d59873ffc1c9a893609f31fe54b639df).
#
# ## Assignments
# ### Formative
# Eight weekly quizzes.
# The quizzes do not provide any marks to your final grade but will help you learn, especially for the class test.
#
# ### Summative
# **Assignment 1: Statistics and Trends**
#
# 20% of final grade. Template python script to be filled out, producing at least 3 plots using techniques taught in lecture.
#
#
# **Class test**:
#
# 20% of final grade. An in-person Canvas quiz, you will not be able to access the quiz if not in the session. Exact date/time to be confirmed but w/b 7th April.
#
#
# **Assignment 2: Clustering and Fitting**
#
# 30% of final grade. Like the statistics and trends assignment but also making use of clustering and fitting techniques taught in the lectures.
#
#
# **CodeGrade Course**
#
# 30% of final grade. Every 2 weeks, you will do several mini-exercises through CodeGrade (links through the Canvas assignment), 30 in total.
#
#
# See assignments tab on Canvas for further details on all of these.
#
# Why are assignments due on Thursdays at midday (12pm)? You are entitled to request a short term extension right up until the deadline. These need to be submitted directly to SASH, who will need time to respond.

# %% [markdown]
# ## Relational Graphs
# Let's first **def**ine a couple of functions, in both the mathematical and pythonic manner.

# %%
def sin2(x):
    """ 
    Calculates sin^2 of x 
    """
    f = np.sin(x) ** 2
    return f

# %%
def circle():
    """ 
    Returns x and y values of the unit circle 
    """
    phi = np.linspace(0.0, 2.0 * np.pi, 1000)
    x = np.cos(phi)
    y = np.sin(phi)
    return x, y

# %% [markdown]
# Note, it is good practice to follow the order: imports -> function/class definitions -> working script.
# In addition, functions should always have a docstring which explains what they do, and what each parameter does.
# In a script, python functions should be seperated from each other by two lines, unless they are in a class, in which case it should be one line.
# As we're in a notebook, good practice is to have a single cell for a single function.

# %%
# calculate the sine of ONE value
x = 2.0
y = np.sin(x)
print("y = ", y)

# create an array with 1000 x values from -10 to 10 (inclusive) and printing first 10
# hint: try also using np.arange, instead.
x = np.linspace(-10.0, 10.0, 1000)
print("x =", x[:10])

# calculate the sine for all values at once
y = np.sin(x)
print("y =", y[:10])
# Out:
# y =  0.9092974268256817
# x = [-10.          -9.97997998  -9.95995996  -9.93993994  -9.91991992
#   -9.8998999   -9.87987988  -9.85985986  -9.83983984  -9.81981982]
# y = [0.54402111 0.52711499 0.5099976  0.49267581 0.47515657 0.45744688
#  0.43955386 0.42148467 0.40324656 0.38484682]

# %%
def plot_sine_cos(x, sinx, cosx):
    """
    Plotting sine and cosine of x array as line graph
    """
    # initialise figure, dpi is the resolution (144 looks good on big screen)
    plt.figure(dpi=144)
    
    # plot line graph, labels are used to produce the legend
    plt.plot(x, sinx, label="sin(x)")
    plt.plot(x, cosx, label="cos(x)")

    # formatting
    # set the upper and lower limits of x
    plt.xlim(-10.0, 10.0)
    # add axis labels
    plt.xlabel("x")
    plt.ylabel("f(x)")
    # add the legend, which uses the labels
    plt.legend(loc="upper left")
    plt.show()
    return

# %%
# "call" that function with the created values
plot_sine_cos(x, np.sin(x), np.cos(x))

# %%
# now with sin^2(x)
def plot_sine_sine2(x, sinx, sin2x):
    """
    Plotting sine and sin^2 of x array as line graph
    """
    # initialise figure, dpi is the resolution (144 looks good on big screen)
    plt.figure(dpi=144)
    
    # plot line graph, labels are used to produce the legend
    plt.plot(x, sinx, label="sin(x)")
    plt.plot(x, sin2x, label="sin2(x)")

    # formatting
    # set the upper and lower limits of x
    plt.xlim(-10.0, 10.0)
    # add axis labels
    plt.xlabel("x")
    plt.ylabel("f(x)")
    # add the legend, which uses the labels
    plt.legend(loc="upper left")
    plt.show()
    return

# %%
plot_sine_sine2(x, np.sin(x), sin2(x))

# %% [markdown]
# Note the differences!
# Also a point to be wary, the third argument in our new function has a very similar name, "sin2x", to the function we defined at the start "sin2".
# Be very careful not to override any variables, this is known as namespace contamination.
# Instead of using plt.show, one can also use plt.savefig('filename.extension') to save the file directly.

# %% [markdown]
# # Question 1
# Recreate the sin and cos graph but using sinh and cosh functions in place (see np.sinh and np.cosh).

# %%
def plot_sinh_cosh(x, sinhx, coshx):
    """
    Plotting sine and cosine of x array as line graph
    """
    # initialise figure, dpi is the resolution (144 looks good on big screen)
    plt.figure(dpi=144)
    
    # plot line graph, labels are used to produce the legend
    plt.plot(x, sinhx, label="sinh(x)")
    plt.plot(x, coshx, label="cosh(x)")

    # formatting
    # set the upper and lower limits of x
    plt.xlim(-10.0, 10.0)
    # add axis labels
    plt.xlabel("x")
    plt.ylabel("f(x)")
    # add the legend, which uses the labels
    plt.legend(loc="upper left")
    plt.show()
    return

plot_sinh_cosh(x, np.sinh(x), np.cosh(x))

# %% [markdown]
# ## End Question 1

# %%
def plot_circle(x, y):
    """
    Plots the unit circle for given x y positions
    """
    plt.figure(dpi=144)
    # plot line graph
    plt.plot(x, y)

    # formatting
    # add axis labels
    plt.xlabel("x")
    plt.ylabel("y")
    # axis equal sets the axis to look square
    plt.axis('equal')
    plt.show()
    return

# %%
# let's "unpack" the variables from the circle function
x, y = circle()
plot_circle(x, y)

# alternatively, plot_circle(*circle()) also unpacks

# %% [markdown]
# # Question 2
# Plot the trigonomical polynomials of cos(at) - cos(bt)^j against sin(ct) - sin(dt)^k, where:
# <ul>
#     <li>t = 0 to 2 * pi (try a different number of steps between those values!)</li>
#     <li>a = 1</li>
#     <li>b = 60</li>
#     <li>c = 1</li>
#     <li>d = 120</li>
#     <li>j = 3</li>
#     <li>k = 4</li>
# </ul>

# %%
a, b, c, d = 1, 60, 1, 120
j, k = 3, 4
t = np.linspace(0, 2 * np.pi, 10000)

# x = np.cos(a * t) - (np.cos(b * t))** j
# print('x',x)
# y = np.sin(c * t) - (np.sin(d * t))** k
# print("y",y)

# %%
def plotFormulas(value1, value2, value3, value4, exponent1, exponent2):
    x = np.cos(value1 * t) - (np.cos(value2 * t))** exponent1
    y = np.sin(value3 * t) - (np.sin(value4 * t))** exponent2
    return x, y

# %%
x, y = plotFormulas(a, b,c,d, j, k)
print("x", x)
print("y", y)

def plotTrignomatry(x,y):
    plt.figure(figsize=(8,8))
    plt.plot(x, y)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.axis('equal')
    plt.show()
    return
# Out:
# x [0.         0.0021303  0.00850001 ... 0.00850001 0.0021303  0.        ]
# y [ 0.00000000e+00  5.96172746e-04  7.47257852e-04 ... -1.76626696e-03
#  -6.60589909e-04 -2.44929360e-16]

# %%
plotTrignomatry(x,y)

# %% [markdown]
# ## End Question 2
# Scatter plots are created in a much similar manner

# %%
# creating random data from 0 to 1
x = np.random.uniform(0, 1, 100)
# creating "noisy" data of the same size
y = x + np.random.normal(0, 0.2, len(x))

# %%
def plot_random_scatter(x, y):
    """
    Creates a scatter plot of random x and y data
    """
    plt.figure(dpi=144)

    # scatter plot
    plt.scatter(x, y, color='blue')
    # another trick: try instead plt.plot(x, y, 'bo')

    # formatting
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
    return

# %%
plot_random_scatter(x, y)

# %% [markdown]
# # Question 3
# Considering we know the data should go from 0 to 1, copy the random scatter plot function above and add an overplotted straight black line. We'll do a better job "fitting" this later in the module!

# %%
def scatter_plot_with_line(x, y):
    plt.scatter(x, y)
    plt.plot([0, 1], [0, 1], color="black")

    plt.xlabel("X values")
    plt.ylabel("Y values")
    plt.title("Random Scatter Plot with Reference Line")
    plt.show()

# %%
scatter_plot_with_line(x, y)

# %% [markdown]
# ## End Question 3
